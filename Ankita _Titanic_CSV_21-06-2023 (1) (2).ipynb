# %% [markdown]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df["Age"].mean()
# Out:
# 29.69911764705882

# %%
df["Age"].fillna(df["Age"].mean(),inplace=True)
#que = find mean of age and fill the null values with mean

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop(["Cabin"],axis=1,inplace=True)
# Que = delete cabin table

# %%
df["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df["Embarked"].fillna("s",inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.describe()
#describe use for only numerical data
# range of age= range between standard daviation and mean
# any data should be in range = (mean-sd)(mean+sd)
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
#to find how many child in age table is below 18

def male_female_child(passenger):   #............passenger is a parameter
    sex,age=passenger
    if age<18:
        return "Child"
    else:
        return sex

# %%
df["person"]=df[["Sex","Age"]].apply(male_female_child,axis=1)          #.feature engennering= apply data in person

# %%
df["person"].value_counts()
# Out:
# male      519
# female    259
# Child     113
# Name: person, dtype: int64

# %%
#repeat example for using variable s and a

def male_female_child(passenger):   #............passenger is a parameter
    s,a=passenger
    if a<18:
        return "Child"
    else:
        return s

# %%
df["person"]=df[["Sex","Age"]].apply(male_female_child,axis=1)

# %%
df["person"].value_counts()
# Out:
# male      519
# female    259
# Child     113
# Name: person, dtype: int64

# %% [markdown]
# # 22-06-2023

# %%
# Que = how many % female and male are there

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  person
# 0      0         A/5 21171   7.2500        S    male
# 1      0          PC 17599  71.2833        C  female
# 2      0  STON/O2. 3101282   7.9250        S  female
# 3      0            113803  53.1000        S  female
# ...

# %%
df["person"].value_counts()/len(df)*100
# Out:
# male      58.249158
# female    29.068462
# Child     12.682379
# Name: person, dtype: float64

# %%
#map function use only one column 
#apply use for whole data

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
#Que = show heatmap
plt.figure(figsize=(6,6))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
# Que = to show pclass and survived data

# %%
plt.figure(figsize=(6,6))
sns.countplot(data=df,x="Pclass",hue="Survived")
plt.show()

# %% [markdown]
# # Student.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("Students.csv")
df
# Out:
#       Rank       Name  Age  Gender Background  Python  Machine Learning
# 0   Rank 1       Ravi   23    Male       Tech      89                95
# 1   Rank 2    Chandni   22  Female   Non-Tech      78                83
# 2   Rank 3    Gyanesh   25    Male       Tech      70                80
# 3   Rank 4      Rahul   22    Male       Tech      68                75
# 4   Rank 5     Kartik   23    Male       Tech      60                70
# 5   Rank 6  Pratiksha   24  Female   Non-Tech      58                55
# 6   Rank 7       Maya   22  Female   Non-Tech      55                50
# 7   Rank 8      Shani   21    Male       Tech      50                50
# 8   Rank 9     Neelam   24  Female   Non-Tech      50                47
# 9  Rank 10     Mangal   22    Male   Non-Tech      45                46

# %%
df.head()
# Out:
#      Rank     Name  Age  Gender Background  Python  Machine Learning
# 0  Rank 1     Ravi   23    Male       Tech      89                95
# 1  Rank 2  Chandni   22  Female   Non-Tech      78                83
# 2  Rank 3  Gyanesh   25    Male       Tech      70                80
# 3  Rank 4    Rahul   22    Male       Tech      68                75
# 4  Rank 5   Kartik   23    Male       Tech      60                70

# %%
# Que add columns as total to dispaly total of python and machine learning

# %%
df["Total"]=df["Python"]+df["Machine Learning"]
df
# Out:
#       Rank       Name  Age  Gender Background  Python  Machine Learning  Total
# 0   Rank 1       Ravi   23    Male       Tech      89                95    184
# 1   Rank 2    Chandni   22  Female   Non-Tech      78                83    161
# 2   Rank 3    Gyanesh   25    Male       Tech      70                80    150
# 3   Rank 4      Rahul   22    Male       Tech      68                75    143
# 4   Rank 5     Kartik   23    Male       Tech      60                70    130
# 5   Rank 6  Pratiksha   24  Female   Non-Tech      58                55    113
# 6   Rank 7       Maya   22  Female   Non-Tech      55                50    105
# 7   Rank 8      Shani   21    Male       Tech      50                50    100
# 8   Rank 9     Neelam   24  Female   Non-Tech      50                47     97
# 9  Rank 10     Mangal   22    Male   Non-Tech      45                46     91

# %%
cities=["thane","pune","thane","dombivli","nagpur","nashik","mumbai","thane","nagpur","mumbai"]
df["City"]=cities
df

#it ts called fetured engeneering
# Out:
#       Rank       Name  Age  Gender Background  Python  Machine Learning  \
# 0   Rank 1       Ravi   23    Male       Tech      89                95
# 1   Rank 2    Chandni   22  Female   Non-Tech      78                83
# 2   Rank 3    Gyanesh   25    Male       Tech      70                80
# 3   Rank 4      Rahul   22    Male       Tech      68                75
# 4   Rank 5     Kartik   23    Male       Tech      60                70
# 5   Rank 6  Pratiksha   24  Female   Non-Tech      58                55
# 6   Rank 7       Maya   22  Female   Non-Tech      55                50
# 7   Rank 8      Shani   21    Male       Tech      50                50
# 8   Rank 9     Neelam   24  Female   Non-Tech      50                47
# 9  Rank 10     Mangal   22    Male   Non-Tech      45                46
#
#    Total      City
# 0    184     thane
# 1    161      pune
# 2    150     thane
# 3    143  dombivli
# 4    130    nagpur
# 5    113    nashik
# 6    105    mumbai
# ...

# %%
# Que = show first letter of city columns in capital
# change city name with first letter in capital

# %%
df["City"]=df["City"].map(lambda x:x.capitalize())    
# capitalize use for make first letter capital

# %%
df
# Out:
#       Rank       Name  Age  Gender Background  Python  Machine Learning  \
# 0   Rank 1       Ravi   23    Male       Tech      89                95
# 1   Rank 2    Chandni   22  Female   Non-Tech      78                83
# 2   Rank 3    Gyanesh   25    Male       Tech      70                80
# 3   Rank 4      Rahul   22    Male       Tech      68                75
# 4   Rank 5     Kartik   23    Male       Tech      60                70
# 5   Rank 6  Pratiksha   24  Female   Non-Tech      58                55
# 6   Rank 7       Maya   22  Female   Non-Tech      55                50
# 7   Rank 8      Shani   21    Male       Tech      50                50
# 8   Rank 9     Neelam   24  Female   Non-Tech      50                47
# 9  Rank 10     Mangal   22    Male   Non-Tech      45                46
#
#    Total      City
# 0    184     Thane
# 1    161      Pune
# 2    150     Thane
# 3    143  Dombivli
# 4    130    Nagpur
# 5    113    Nashik
# 6    105    Mumbai
# ...

# %%
df.City=df.City.str.title()
print(df.City)
# Out:
# 0       Thane
# 1        Pune
# 2       Thane
# 3    Dombivli
# 4      Nagpur
# 5      Nashik
# 6      Mumbai
# 7       Thane
# 8      Nagpur
# 9      Mumbai
# Name: City, dtype: object

# %%
df
# Out:
#       Rank       Name  Age  Gender Background  Python  Machine Learning  \
# 0   Rank 1       Ravi   23    Male       Tech      89                95
# 1   Rank 2    Chandni   22  Female   Non-Tech      78                83
# 2   Rank 3    Gyanesh   25    Male       Tech      70                80
# 3   Rank 4      Rahul   22    Male       Tech      68                75
# 4   Rank 5     Kartik   23    Male       Tech      60                70
# 5   Rank 6  Pratiksha   24  Female   Non-Tech      58                55
# 6   Rank 7       Maya   22  Female   Non-Tech      55                50
# 7   Rank 8      Shani   21    Male       Tech      50                50
# 8   Rank 9     Neelam   24  Female   Non-Tech      50                47
# 9  Rank 10     Mangal   22    Male   Non-Tech      45                46
#
#    Total      City
# 0    184     Thane
# 1    161      Pune
# 2    150     Thane
# 3    143  Dombivli
# 4    130    Nagpur
# 5    113    Nashik
# 6    105    Mumbai
# ...

# %%
#Que = show grade column ....
# avg>=80............A
# avg<80 and >70..............B
# avg<70 and >60........B+
# otherwise.........C
#avg=total/2

# %%
def avg(marks):
    avg=marks
    if avg>=80:
        return "A"
    elif avg<80 and avg>70:
        return "B"
    elif avg<70 and avg>60:
        return "B+"
    else:
        return "C"

# %%
df["Grade"]=df["Total"].apply(avg)

# %%
df
# Out:
#       Rank       Name  Age  Gender Background  Python  Machine Learning  \
# 0   Rank 1       Ravi   23    Male       Tech      89                95
# 1   Rank 2    Chandni   22  Female   Non-Tech      78                83
# 2   Rank 3    Gyanesh   25    Male       Tech      70                80
# 3   Rank 4      Rahul   22    Male       Tech      68                75
# 4   Rank 5     Kartik   23    Male       Tech      60                70
# 5   Rank 6  Pratiksha   24  Female   Non-Tech      58                55
# 6   Rank 7       Maya   22  Female   Non-Tech      55                50
# 7   Rank 8      Shani   21    Male       Tech      50                50
# 8   Rank 9     Neelam   24  Female   Non-Tech      50                47
# 9  Rank 10     Mangal   22    Male   Non-Tech      45                46
#
#    Total      City Grade
# 0    184     Thane     A
# 1    161      Pune     A
# 2    150     Thane     A
# 3    143  Dombivli     A
# 4    130    Nagpur     A
# ...
