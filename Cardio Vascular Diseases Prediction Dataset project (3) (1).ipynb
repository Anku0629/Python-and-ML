# %% [markdown]
# # Cardio Vascular Diseases Prediction Dataset

# %% [markdown]
# ### Introduction
#
#
# Cardiovascular diseases are the leading cause of death globally. It is therefore necessary to identify the causes and develop a system to predict heart attacks in an effective manner. The data below has the information about the factors that might have an impact on cardiovascular health.
#
#
# Variable	Description
#
# Age     -	Age in years
#
# Sex     -	1 = male; 0 = female
#
# cp      -	Chest pain type
#
# trestbps-	Resting blood pressure (in mm Hg on admission to the hospital)
#
# chol    -	Serum cholesterol in mg/dl
#
# fbs     -	Fasting blood sugar > 120 mg/dl (1 = true; 0 = false)
#
# restecg -	Resting electrocardiographic results
#
# thalach -	Maximum heart rate achieved
#
# exang   -	Exercise induced angina (1 = yes; 0 = no)
#
# oldpeak -	ST depression induced by exercise relative to rest
#
# slope	-   Slope of the peak exercise ST segment
#
# ca      -	Number of major vessels (0-3) colored by fluoroscopy
#
# thal    -	3 = normal; 6 = fixed defect; 7 = reversible defect
#
# Target  -	1 or 0

# %% [markdown]
# ### Import all the liabraries -
#
# Pandas - Used to analyse data. It has function for analysing,cleaning,exploring and manipulating data.
#
# Numpy - Mostly work on numerical values for making Arithmatic Operations.
#
# Matplotlib - Comprehensive library for creating static,animated and intractive visualization.
#
# Seaborn - Seaborn is a python data visualization library based on matplotlib. It provides a high-level interface for drawing intractive and informative statastical graphics.
#
#
#
#
#
#
#
# Warnings - warnings are provided to warn the developer of situation that are not necessarily exceptions and ignore them.

# %% [markdown]
# ### By read_csv() function we are reading the dataset present in " Cardio_vascular .csv" file.
#
# Took dataset from Kaggle
#
# Will be making predictions models using Machine Learning Algorithams.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Cardio_vascular.csv")

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      51    1   0       125   212    0        1      168      0      1.0
# 1      54    1   0       140   203    1        0      155      1      3.1
# 2      71    1   0       145   174    0        1      125      1      2.6
# 3      60    1   0       148   203    0        1      161      0      0.0
# 4      61    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       173   221    0        1      164      1      1.2
# 1021   60    1   0       174   258    0        0      141      1      1.4
# 1022   47    1   0       173   275    0        0      118      1      0.0
# 1023   50    0   0       165   254    0        0      159      0      3.8
# 1024   54    1   0       168   188    0        1      113      0      0.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %% [markdown]
# #### Find information about Data by using df.info()
#
# This Cardio_vascular .csv dataset contains the information of patients cardiovascular health condition through their parameters with 1025 rows and 14 columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# This dataset contain 1025 rows and 14 columns out of there are 14 numerical columns.

# %% [markdown]
# ### To find Correlation between each other

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.104937 -0.070593  0.029977  0.222366  0.120954
# sex      -0.104937  1.000000 -0.041119  0.005460 -0.197402  0.027200
# cp       -0.070593 -0.041119  1.000000  0.002781 -0.083173  0.079294
# trestbps  0.029977  0.005460  0.002781  1.000000 -0.008791 -0.004151
# chol      0.222366 -0.197402 -0.083173 -0.008791  1.000000  0.028230
# fbs       0.120954  0.027200  0.079294 -0.004151  0.028230  1.000000
# restecg  -0.133820 -0.055117  0.043581  0.044977 -0.152561 -0.104051
# thalach  -0.388803 -0.046461  0.306891 -0.023886 -0.032125 -0.007197
# exang     0.086871  0.139157 -0.401513  0.045782  0.070733  0.049261
# oldpeak   0.166704  0.065381 -0.143087  0.000798  0.077354  0.017457
# slope    -0.168845 -0.026666  0.131633 -0.006981 -0.035621 -0.061902
# ca        0.269580  0.111729 -0.176206  0.018228  0.078979  0.137156
# thal      0.071204  0.198424 -0.163341  0.041288  0.111716 -0.042177
# target   -0.228005 -0.279501  0.434854  0.002197 -0.111634 -0.041164
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.133820 -0.388803  0.086871  0.166704 -0.168845  0.269580
# sex      -0.055117 -0.046461  0.139157  0.065381 -0.026666  0.111729
# cp        0.043581  0.306891 -0.401513 -0.143087  0.131633 -0.176206
# trestbps  0.044977 -0.023886  0.045782  0.000798 -0.006981  0.018228
# chol     -0.152561 -0.032125  0.070733  0.077354 -0.035621  0.078979
# fbs      -0.104051 -0.007197  0.049261  0.017457 -0.061902  0.137156
# restecg   1.000000  0.051017 -0.065606 -0.056302  0.086086 -0.078072
# thalach   0.051017  1.000000 -0.380339 -0.289209  0.394319 -0.206177
# exang    -0.065606 -0.380339  1.000000  0.233706 -0.267335  0.107849
# oldpeak  -0.056302 -0.289209  0.233706  1.000000 -0.445506  0.181624
# slope     0.086086  0.394319 -0.267335 -0.445506  1.000000 -0.073440
# ca       -0.078072 -0.206177  0.107849  0.181624 -0.073440  1.000000
# thal     -0.020504 -0.093134  0.197201  0.171535 -0.094090  0.149014
# target    0.134468  0.422711 -0.438029 -0.364248  0.345512 -0.382085
#
#               thal    target
# age       0.071204 -0.228005
# sex       0.198424 -0.279501
# cp       -0.163341  0.434854
# trestbps  0.041288  0.002197
# chol      0.111716 -0.111634
# fbs      -0.042177 -0.041164
# restecg  -0.020504  0.134468
# thalach  -0.093134  0.422711
# exang     0.197201 -0.438029
# oldpeak   0.171535 -0.364248
# slope    -0.094090  0.345512
# ca        0.149014 -0.382085
# thal      1.000000 -0.337838
# target   -0.337838  1.000000

# %% [markdown]
# ### To check skewness of the data

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps         chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean     54.458537     0.695610     0.942439   148.078049   246.668293
# std       9.054764     0.460373     1.029641    23.059022    51.789267
# min      29.000000     0.000000     0.000000    71.000000   126.000000
# 25%      48.000000     0.000000     0.000000   131.000000   211.000000
# 50%      56.000000     1.000000     1.000000   151.000000   240.000000
# 75%      61.000000     1.000000     2.000000   165.000000   276.000000
# max      77.000000     1.000000     3.000000   202.000000   564.000000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.218537     0.336585     1.052976
# std       0.356527     0.527878    23.002315     0.472772     1.191635
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.600000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %% [markdown]
# #### Shows Relationship Between each other

# %%
sns.pairplot(df)

# %% [markdown]
# ### Splitting Data Into Features and Target

# %%
x=df.iloc[:,:-1]
x
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      51    1   0       125   212    0        1      168      0      1.0
# 1      54    1   0       140   203    1        0      155      1      3.1
# 2      71    1   0       145   174    0        1      125      1      2.6
# 3      60    1   0       148   203    0        1      161      0      0.0
# 4      61    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       173   221    0        1      164      1      1.2
# 1021   60    1   0       174   258    0        0      141      1      1.4
# 1022   47    1   0       173   275    0        0      118      1      0.0
# 1023   50    0   0       165   254    0        0      159      0      3.8
# 1024   54    1   0       168   188    0        1      113      0      0.4
#
#       slope  ca  thal
# 0         2   2     3
# 1         0   0     3
# 2         0   0     3
# 3         2   1     3
# 4         1   3     2
# ...     ...  ..   ...
# 1020      2   0     2
# 1021      1   1     3
# 1022      1   1     2
# 1023      2   0     2
# 1024      1   1     3
#
# [1025 rows x 13 columns]

# %% [markdown]
# We are splitting overall data except target column that is "target" in x variable

# %%
y=df["target"]
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %% [markdown]
# In that separate "target" column as a target in y variable.

# %%
df["target"].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %% [markdown]
# Our target column having data.i.e 1=526 and 0=499.

# %% [markdown]
# #### Apply Standard Scaler to Scale the data at one level

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# By using standard scaler we have data in one level

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=1)

# %% [markdown]
# For standard scaler we need to split data into training and testing parts, in that testing data is 20% and random state is 1.

# %%
sc=StandardScaler()
xtrain=sc.fit_transform(xtrain)
xtest=sc.fit_transform(xtest)

# %% [markdown]
# We make object of standard scaler.
# In that we have to pass xtrain and xtest for transform into standard scaler.

# %%
xtrain
# Out:
# array([[ 0.27803227,  0.68138514, -0.91755375, ...,  0.99674422,
#         -0.72634942,  1.11342872],
#        [ 0.49959346,  0.68138514,  2.05633589, ...,  0.99674422,
#          1.23611029, -0.5227927 ],
#        [ 0.83193525, -1.46759877, -0.91755375, ..., -0.61534702,
#         -0.72634942, -0.5227927 ],
#        ...,
#        [ 0.16725168,  0.68138514, -0.91755375, ..., -0.61534702,
#          0.25488044, -0.5227927 ],
#        [ 0.83193525,  0.68138514, -0.91755375, ..., -0.61534702,
#          1.23611029,  1.11342872],
#        [ 1.05349644,  0.68138514,  2.05633589, ..., -0.61534702,
#         -0.72634942,  1.11342872]])

# %% [markdown]
# This is our standardize xtrain data on which we performed Standard Scaling

# %%
xtest
# Out:
# array([[ 0.61998548,  0.58298309, -0.91440872, ...,  0.99064776,
#          1.11030741,  1.00455772],
#        [-0.36441487, -1.71531562,  0.89673899, ...,  0.99064776,
#         -0.75537307, -0.52088178],
#        [-1.34881522,  0.58298309, -0.00883487, ...,  0.99064776,
#         -0.75537307, -0.52088178],
#        ...,
#        [-0.03628142,  0.58298309, -0.91440872, ..., -0.66043184,
#          0.17746717,  1.00455772],
#        [-1.78632649,  0.58298309,  0.89673899, ...,  0.99064776,
#          2.97598789, -0.52088178],
#        [ 0.07309639,  0.58298309, -0.91440872, ..., -0.66043184,
#          0.17746717,  1.00455772]])

# %% [markdown]
# This is our standardize xtest data on which we performed Standard Scaling

# %% [markdown]
# #### Train_Test_Split for separating data into training and testing phase

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=1)

# %% [markdown]
# To build a module we have to saperate x and y for training and testing. In that test size is 20% and random state is 1.

# %% [markdown]
# #### Build a Model by using LogisticRegression Algoritham

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# From class sklearn.linear_model build a model Logistic Regression

# %%
lr=LogisticRegression()
lr.fit(xtrain,ytrain)
ypred_train=lr.predict(xtrain)
ypred_test=lr.predict(xtest)

# %% [markdown]
# Craete a object of this class and fit() method is used in order to train the model and use it for predictions.
#
# ypred_train is variable that stored predicted values by model of training data.
#
# ypred_test is variable that stored predicted values by model of testing data.

# %% [markdown]
# #### Classification Report of model trained on Logistic Regression

# %%
from sklearn.metrics import classification_report

# %%
print("Train Data")
print(classification_report(ytrain,ypred_train))
print("Test Data")
print(classification_report(ytest,ypred_test))
# Out:
# Train Data
#               precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84       390
#            1       0.83      0.90      0.87       430
#
#     accuracy                           0.85       820
#    macro avg       0.86      0.85      0.85       820
# weighted avg       0.86      0.85      0.85       820
#
# Test Data
#               precision    recall  f1-score   support
#
#            0       0.89      0.75      0.82       109
#            1       0.76      0.90      0.82        96
#
#     accuracy                           0.82       205
#    macro avg       0.83      0.82      0.82       205
# weighted avg       0.83      0.82      0.82       205

# %% [markdown]
# According to classification Report accuracy of training data is 85% and testing data is 82%. This is best fitted model.

# %% [markdown]
# #### By using Hyperparameter or Hypertunners

# %%
lr=LogisticRegression(solver="liblinear")
lr.fit(xtrain,ytrain)
ypred_train=lr.predict(xtrain)
ypred_test=lr.predict(xtest)

# %%
print("Train Data")
print(classification_report(ytrain,ypred_train))
print("Test Data")
print(classification_report(ytest,ypred_test))
# Out:
# Train Data
#               precision    recall  f1-score   support
#
#            0       0.87      0.80      0.83       390
#            1       0.83      0.89      0.86       430
#
#     accuracy                           0.85       820
#    macro avg       0.85      0.85      0.85       820
# weighted avg       0.85      0.85      0.85       820
#
# Test Data
#               precision    recall  f1-score   support
#
#            0       0.88      0.74      0.81       109
#            1       0.75      0.89      0.81        96
#
#     accuracy                           0.81       205
#    macro avg       0.82      0.81      0.81       205
# weighted avg       0.82      0.81      0.81       205

# %%
lr=LogisticRegression(solver="sag")
lr.fit(xtrain,ytrain)
ypred_train=lr.predict(xtrain)
ypred_test=lr.predict(xtest)

# %%
print("Train Data")
print(classification_report(ytrain,ypred_train))
print("Test Data")
print(classification_report(ytest,ypred_test))
# Out:
# Train Data
#               precision    recall  f1-score   support
#
#            0       0.73      0.68      0.71       390
#            1       0.73      0.77      0.75       430
#
#     accuracy                           0.73       820
#    macro avg       0.73      0.73      0.73       820
# weighted avg       0.73      0.73      0.73       820
#
# Test Data
#               precision    recall  f1-score   support
#
#            0       0.77      0.66      0.71       109
#            1       0.67      0.78      0.72        96
#
#     accuracy                           0.72       205
#    macro avg       0.72      0.72      0.72       205
# weighted avg       0.73      0.72      0.72       205

# %%
lr=LogisticRegression(solver="saga")
lr.fit(xtrain,ytrain)
ypred_train=lr.predict(xtrain)
ypred_test=lr.predict(xtest)

# %%
print("Train Data")
print(classification_report(ytrain,ypred_train))
print("Test Data")
print(classification_report(ytest,ypred_test))
# Out:
# Train Data
#               precision    recall  f1-score   support
#
#            0       0.71      0.67      0.69       390
#            1       0.71      0.75      0.73       430
#
#     accuracy                           0.71       820
#    macro avg       0.71      0.71      0.71       820
# weighted avg       0.71      0.71      0.71       820
#
# Test Data
#               precision    recall  f1-score   support
#
#            0       0.74      0.63      0.68       109
#            1       0.64      0.75      0.69        96
#
#     accuracy                           0.69       205
#    macro avg       0.69      0.69      0.69       205
# weighted avg       0.70      0.69      0.69       205

# %% [markdown]
# By using Hypertunning Parameters i.e "liblenear", "sag","saga" we have best fit model.

# %% [markdown]
# #### Build a model by using KNN Algoritham

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# From class sklearn.neighbors build a model KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(xtrain,ytrain)
ypred_train=knn.predict(xtrain)
ypred_test=knn.predict(xtest)

# %% [markdown]
# Craete a object of this class and fit() method is used in order to train the model and use it for predictions.
#
# ypred_train is variable that stored predicted values by model of training data.
#
# ypred_test is variable that stored predicted values by model of testing data.

# %% [markdown]
# #### Evaluate the model by using Classification_report

# %%
from sklearn.metrics import classification_report

# %%
print("Train Data")
print(classification_report(ytrain,ypred_train))
print("Test Data")
print(classification_report(ytest,ypred_test))
# Out:
# Train Data
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79       390
#            1       0.80      0.83      0.82       430
#
#     accuracy                           0.80       820
#    macro avg       0.80      0.80      0.80       820
# weighted avg       0.80      0.80      0.80       820
#
# Test Data
#               precision    recall  f1-score   support
#
#            0       0.73      0.61      0.66       109
#            1       0.62      0.74      0.68        96
#
#     accuracy                           0.67       205
#    macro avg       0.67      0.67      0.67       205
# weighted avg       0.68      0.67      0.67       205

# %% [markdown]
# According to classification Report accuracy of training data is 80% and testing data is 67%. This is best fitted model.

# %% [markdown]
# #### Build a model on SVM Algoritham

# %%
from sklearn.svm import SVC

# %% [markdown]
# From class sklearn.svm build a model svc(suport vector machine)

# %%
svm=SVC()

# %% [markdown]
# Create A object of class svm

# %%
def mymodel(model):
    model.fit(xtrain,ytrain)
    ypred=model.predict(xtest)
    print(classification_report(ytest,ypred))
    return model

# %% [markdown]
# We are making one function i.e mymodel in that we have to pass our model name.
#
# Fit() method is used in order to train the model and use it for predictions.
#
# Predicted values are stored in a ypred variable.
#
# we have to print classification report of this model for predict accuracy of trainning data.
#
# In return we have to pass name of our module

# %%
from sklearn.pipeline import Pipeline

# %% [markdown]
# From class sklearn.pipline we have to import Pipeline
#
# We using pipeline beacause data should be process smoothly.

# %%
pipe=Pipeline(steps=[('scaler',StandardScaler()),('svm',SVC())])

# %% [markdown]
# In pipe we write steps so that steps will be executed one by one

# %%
pipe.fit(xtrain,ytrain)
ypred=pipe.predict(xtest)

# %%
mymodel(svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.57      0.65       109
#            1       0.61      0.78      0.69        96
#
#     accuracy                           0.67       205
#    macro avg       0.68      0.68      0.67       205
# weighted avg       0.69      0.67      0.67       205
# SVC()

# %% [markdown]
# fit() method is used in order to train the model and use it for predictions.
#
# ypred is variable that stored predicted values by model of testing data
#
# We have to call the function and pass model name

# %% [markdown]
# #### By using Hyperparameter or Hypertunners

# %%
svm=SVC(kernel='linear')
mymodel(svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.74      0.82       109
#            1       0.76      0.92      0.83        96
#
#     accuracy                           0.82       205
#    macro avg       0.83      0.83      0.82       205
# weighted avg       0.84      0.82      0.82       205
# SVC(kernel='linear')

# %% [markdown]
# By using linear kernel i.e hypertunning parameter we are having accuracy 82%.

# %%
svm=SVC(kernel='sigmoid')
mymodel(svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.45      0.51       109
#            1       0.50      0.62      0.56        96
#
#     accuracy                           0.53       205
#    macro avg       0.54      0.54      0.53       205
# weighted avg       0.54      0.53      0.53       205
# SVC(kernel='sigmoid')

# %% [markdown]
# By using sigmoid kernel i.e hypertunning parameter we are having accuracy 53%. Its very low accuracy.

# %%
svm=SVC(kernel='poly')
mymodel(svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.59      0.66       109
#            1       0.62      0.78      0.69        96
#
#     accuracy                           0.68       205
#    macro avg       0.69      0.68      0.68       205
# weighted avg       0.69      0.68      0.68       205
# SVC(kernel='poly')

# %% [markdown]
# By using poly kernel i.e hypertunning parameter we are having accuracy 68%.

# %% [markdown]
# #### Build a model by using Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# From class sklearn.tree build a model Decision Tree Classifier

# %%
dt=DecisionTreeClassifier()
dt.fit(xtrain,ytrain)
ytrain_pred=dt.predict(xtrain)
ytest_pred=dt.predict(xtest)

# %% [markdown]
# Craete a object of this class and fit() method is used in order to train the model and use it for predictions.
#
# ypred_train is variable that stored predicted values by model of training data.
#
# ypred_test is variable that stored predicted values by model of testing data.

# %% [markdown]
# #### Evaluate the model by using Classification_report

# %%
from sklearn.metrics import classification_report,accuracy_score

# %%
print("Train Data")
print(classification_report(ytrain,ytrain_pred))
print("Test Data")
print(classification_report(ytest,ytest_pred))
# Out:
# Train Data
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       390
#            1       1.00      1.00      1.00       430
#
#     accuracy                           1.00       820
#    macro avg       1.00      1.00      1.00       820
# weighted avg       1.00      1.00      1.00       820
#
# Test Data
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       109
#            1       0.94      0.93      0.93        96
#
#     accuracy                           0.94       205
#    macro avg       0.94      0.94      0.94       205
# weighted avg       0.94      0.94      0.94       205

# %% [markdown]
# According to classification Report accuracy of training data is 100% its high bias and testing data is 96% its variance is high. Beacause of this scenario it is underfitted model.

# %% [markdown]
# #### Performing Hypertunning on model

# %% [markdown]
# #### Hyper parameters with impurity checking gini

# %%
for i in range(1,31):
    dt1=DecisionTreeClassifier(max_depth=i)
    dt1.fit(xtrain,ytrain)
    ypred=dt1.predict(xtest)
    ac=accuracy_score(ytest,ypred)
    print(f"Max Depth:{i} accuracy): {ac}")
# Out:
# Max Depth:1 accuracy): 0.7609756097560976
# Max Depth:2 accuracy): 0.7609756097560976
# Max Depth:3 accuracy): 0.8195121951219512
# Max Depth:4 accuracy): 0.8292682926829268
# Max Depth:5 accuracy): 0.8634146341463415
# Max Depth:6 accuracy): 0.9024390243902439
# Max Depth:7 accuracy): 0.9121951219512195
# Max Depth:8 accuracy): 0.9365853658536586
# Max Depth:9 accuracy): 0.9365853658536586
# Max Depth:10 accuracy): 0.9414634146341463
# Max Depth:11 accuracy): 0.926829268292683
# Max Depth:12 accuracy): 0.9414634146341463
# Max Depth:13 accuracy): 0.9463414634146341
# Max Depth:14 accuracy): 0.9463414634146341
# Max Depth:15 accuracy): 0.9414634146341463
# Max Depth:16 accuracy): 0.9463414634146341
# Max Depth:17 accuracy): 0.9414634146341463
# Max Depth:18 accuracy): 0.9463414634146341
# Max Depth:19 accuracy): 0.9463414634146341
# Max Depth:20 accuracy): 0.9365853658536586
# Max Depth:21 accuracy): 0.9414634146341463
# Max Depth:22 accuracy): 0.9463414634146341
# Max Depth:23 accuracy): 0.9463414634146341
# Max Depth:24 accuracy): 0.9414634146341463
# Max Depth:25 accuracy): 0.9512195121951219
# Max Depth:26 accuracy): 0.9463414634146341
# Max Depth:27 accuracy): 0.9365853658536586
# Max Depth:28 accuracy): 0.9414634146341463
# Max Depth:29 accuracy): 0.9414634146341463
# Max Depth:30 accuracy): 0.9365853658536586

# %% [markdown]
# We splin a loop in range 1 to 31, Dt model apply on this range and this values are stored into dt1 variable.
#
# Fit() method is used in order to train the model and use it for predictions.
#
# Ypred is a variable its stored predicted values of xtest
#
# Accuracy score of this values are stored in ac variable.
#
# print maximum depth and accuracy score of each .

# %% [markdown]
# #### Building model with final value of max depth as 9

# %%
dt1=DecisionTreeClassifier(max_depth=9)
mymodel(dt1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       109
#            1       0.91      0.94      0.92        96
#
#     accuracy                           0.93       205
#    macro avg       0.93      0.93      0.93       205
# weighted avg       0.93      0.93      0.93       205
# DecisionTreeClassifier(max_depth=9)

# %% [markdown]
# In these accuracy we want to select the max depth in wich accuracy score is decreases. In these scenario max depth 9 is the point when accuracy score was decrease.
#
# With the help of gini index Hypertunning parameter accuracy is be 95%.
# it is overfitting model.

# %% [markdown]
# #### Lets checking overfitting scenario

# %%
dt1.score(xtrain,ytrain)
# Out:
# 0.998780487804878

# %% [markdown]
# With the help of gini index Hypertunning parameter model is over fitted.

# %% [markdown]
# #### Hyper parameters with impurity checking min_sample_split

# %%
for i in range(5,50):
    dt3=DecisionTreeClassifier(min_samples_split=i)
    dt3.fit(xtrain,ytrain)
    ypred=dt3.predict(xtest)
    ac=accuracy_score(ytest,ypred)
    print(f"min sample split:{i} accuracy): {ac}")
# Out:
# min sample split:5 accuracy): 0.926829268292683
# min sample split:6 accuracy): 0.9121951219512195
# min sample split:7 accuracy): 0.9121951219512195
# min sample split:8 accuracy): 0.9121951219512195
# min sample split:9 accuracy): 0.9121951219512195
# min sample split:10 accuracy): 0.9121951219512195
# min sample split:11 accuracy): 0.9024390243902439
# min sample split:12 accuracy): 0.9073170731707317
# min sample split:13 accuracy): 0.9073170731707317
# min sample split:14 accuracy): 0.9073170731707317
# min sample split:15 accuracy): 0.9073170731707317
# min sample split:16 accuracy): 0.9073170731707317
# min sample split:17 accuracy): 0.9073170731707317
# min sample split:18 accuracy): 0.9121951219512195
# min sample split:19 accuracy): 0.9073170731707317
# min sample split:20 accuracy): 0.8829268292682927
# min sample split:21 accuracy): 0.8829268292682927
# min sample split:22 accuracy): 0.8829268292682927
# min sample split:23 accuracy): 0.8682926829268293
# min sample split:24 accuracy): 0.8682926829268293
# min sample split:25 accuracy): 0.8682926829268293
# min sample split:26 accuracy): 0.8682926829268293
# min sample split:27 accuracy): 0.8682926829268293
# min sample split:28 accuracy): 0.8682926829268293
# min sample split:29 accuracy): 0.8634146341463415
# min sample split:30 accuracy): 0.8682926829268293
# min sample split:31 accuracy): 0.8682926829268293
# min sample split:32 accuracy): 0.8634146341463415
# min sample split:33 accuracy): 0.8634146341463415
# min sample split:34 accuracy): 0.8634146341463415
# min sample split:35 accuracy): 0.8634146341463415
# min sample split:36 accuracy): 0.8634146341463415
# min sample split:37 accuracy): 0.8682926829268293
# min sample split:38 accuracy): 0.8682926829268293
# min sample split:39 accuracy): 0.8682926829268293
# min sample split:40 accuracy): 0.8634146341463415
# min sample split:41 accuracy): 0.8634146341463415
# min sample split:42 accuracy): 0.8634146341463415
# min sample split:43 accuracy): 0.8634146341463415
# min sample split:44 accuracy): 0.8634146341463415
# min sample split:45 accuracy): 0.8634146341463415
# min sample split:46 accuracy): 0.8634146341463415
# min sample split:47 accuracy): 0.8634146341463415
# min sample split:48 accuracy): 0.8634146341463415
# min sample split:49 accuracy): 0.8634146341463415

# %% [markdown]
# We splin a loop in range 5 to 50, Dt model apply on this range and this values are stored into dt3 variable.
#
# Fit() method is used in order to train the model and use it for predictions.
#
# Ypred is a variable its stored predicted values of xtest
#
# Accuracy score of this values are stored in ac variable.
#
# print values if min_samples_split and accuracy score of each .

# %% [markdown]
# #### Building model with inal value of max depth as 10

# %%
dt3=DecisionTreeClassifier(min_samples_split=10)
mymodel(dt3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92       109
#            1       0.91      0.91      0.91        96
#
#     accuracy                           0.91       205
#    macro avg       0.91      0.91      0.91       205
# weighted avg       0.91      0.91      0.91       205
# DecisionTreeClassifier(min_samples_split=10)

# %% [markdown]
# In these accuracy we want to select the values ofmin_samples_split in wich accuracy score is decreases. In these scenario min_samples_split=8 is the point when accuracy score was decrease.
#
# With the help of min_samples_split Hypertunning parameter accuracy is be 91%. this is overfitting model.

# %% [markdown]
# #### Lets checking overfitting scenario

# %%
dt3.score(xtrain,ytrain)
# Out:
# 0.9609756097560975

# %% [markdown]
# With the help of min_samples_split Hypertunning parameter model is over fitted.

# %% [markdown]
# #### Hyper parameters with impurity checking min_sample_leaf

# %%
for i in range(5,51):
    dt4=DecisionTreeClassifier(min_samples_leaf=i)
    dt4.fit(xtrain,ytrain)
    ypred=dt4.predict(xtest)
    ac=accuracy_score(ytest,ypred)
    print(f"min sample leaf:{i} accuracy): {ac}")
# Out:
# min sample leaf:5 accuracy): 0.8731707317073171
# min sample leaf:6 accuracy): 0.8926829268292683
# min sample leaf:7 accuracy): 0.8926829268292683
# min sample leaf:8 accuracy): 0.8780487804878049
# min sample leaf:9 accuracy): 0.8975609756097561
# min sample leaf:10 accuracy): 0.8829268292682927
# min sample leaf:11 accuracy): 0.8731707317073171
# min sample leaf:12 accuracy): 0.8682926829268293
# min sample leaf:13 accuracy): 0.8682926829268293
# min sample leaf:14 accuracy): 0.8682926829268293
# min sample leaf:15 accuracy): 0.8682926829268293
# min sample leaf:16 accuracy): 0.8682926829268293
# min sample leaf:17 accuracy): 0.8682926829268293
# min sample leaf:18 accuracy): 0.8780487804878049
# min sample leaf:19 accuracy): 0.8878048780487805
# min sample leaf:20 accuracy): 0.8780487804878049
# min sample leaf:21 accuracy): 0.8780487804878049
# min sample leaf:22 accuracy): 0.8780487804878049
# min sample leaf:23 accuracy): 0.8780487804878049
# min sample leaf:24 accuracy): 0.8780487804878049
# min sample leaf:25 accuracy): 0.8780487804878049
# min sample leaf:26 accuracy): 0.8780487804878049
# min sample leaf:27 accuracy): 0.8780487804878049
# min sample leaf:28 accuracy): 0.8731707317073171
# min sample leaf:29 accuracy): 0.8731707317073171
# min sample leaf:30 accuracy): 0.8536585365853658
# min sample leaf:31 accuracy): 0.8536585365853658
# min sample leaf:32 accuracy): 0.8536585365853658
# min sample leaf:33 accuracy): 0.8536585365853658
# min sample leaf:34 accuracy): 0.8536585365853658
# min sample leaf:35 accuracy): 0.8536585365853658
# min sample leaf:36 accuracy): 0.8536585365853658
# min sample leaf:37 accuracy): 0.8536585365853658
# min sample leaf:38 accuracy): 0.8536585365853658
# min sample leaf:39 accuracy): 0.8536585365853658
# min sample leaf:40 accuracy): 0.8341463414634146
# min sample leaf:41 accuracy): 0.8341463414634146
# min sample leaf:42 accuracy): 0.8341463414634146
# min sample leaf:43 accuracy): 0.8146341463414634
# min sample leaf:44 accuracy): 0.8146341463414634
# min sample leaf:45 accuracy): 0.8146341463414634
# min sample leaf:46 accuracy): 0.8146341463414634
# min sample leaf:47 accuracy): 0.8146341463414634
# min sample leaf:48 accuracy): 0.8146341463414634
# min sample leaf:49 accuracy): 0.8146341463414634
# min sample leaf:50 accuracy): 0.8146341463414634

# %% [markdown]
# We splin a loop in range 1 to 51, Dt model apply on this range and this values are stored into dt4 variable.
#
# Fit() method is used in order to train the model and use it for predictions.
#
# Ypred is a variable its stored predicted values of xtest
#
# Accuracy score of this values are stored in ac variable.
#
# print values if min_samples_leaf and accuracy score of each .

# %% [markdown]
# #### Building model with final value of max depth as 6

# %%
dt4=DecisionTreeClassifier(min_samples_split=6)
mymodel(dt4)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91       109
#            1       0.91      0.90      0.90        96
#
#     accuracy                           0.91       205
#    macro avg       0.91      0.91      0.91       205
# weighted avg       0.91      0.91      0.91       205
# DecisionTreeClassifier(min_samples_split=6)

# %% [markdown]
# In these accuracy we want to select the values of min_samples_leaf in wich accuracy score is decreases. In these scenario min_samples_leaf=8 is the point when accuracy score was decrease.
#
# With the help of min_samples_leaf Hypertunning parameter accuracy is be 91% which is over fitting model.

# %% [markdown]
# #### Lets checking overfitting scenario

# %%
dt4.score(xtrain,ytrain)
# Out:
# 0.9841463414634146

# %% [markdown]
# With the help of min_samples_leaf Hypertunning parameter model is over fitted.

# %% [markdown]
# ## Bagging

# %%
from sklearn.ensemble import BaggingClassifier

# %% [markdown]
# From class sklearn.ensemble build a model BaggingClassifier

# %%
bg=BaggingClassifier(LogisticRegression())
bg.fit(xtrain,ytrain)
ypred_train=bg.predict(xtrain)
ypred_test=bg.predict(xtest)

# %% [markdown]
# Craete a object of this class and pass a module (Logistic regression) in that and fit() method is used in order to train the model and use it for predictions.
#
# ypred_train is variable that stored predicted values by model of training data.
#
# ypred_test is variable that stored predicted values by model of testing data.

# %% [markdown]
# #### Classification Report

# %%
print("Train Data")
print(classification_report(ytrain,ypred_train))
print("Test Data")
print(classification_report(ytest,ypred_test))
# Out:
# Train Data
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84       390
#            1       0.84      0.90      0.87       430
#
#     accuracy                           0.86       820
#    macro avg       0.86      0.85      0.86       820
# weighted avg       0.86      0.86      0.86       820
#
# Test Data
#               precision    recall  f1-score   support
#
#            0       0.89      0.74      0.81       109
#            1       0.75      0.90      0.82        96
#
#     accuracy                           0.81       205
#    macro avg       0.82      0.82      0.81       205
# weighted avg       0.83      0.81      0.81       205

# %% [markdown]
# According to classification Report accuracy through Logistic Regression of training data is 85% and testing data is 83%. This is best fitted model.

# %%
bg=BaggingClassifier(DecisionTreeClassifier())
bg.fit(xtrain,ytrain)
ypred_train=bg.predict(xtrain)
ypred_test=bg.predict(xtest)

# %% [markdown]
# Craete a object of this class and pass a module (DecisionTreeClassifier) in that and fit() method is used in order to train the model and use it for predictions.
#
# ypred_train is variable that stored predicted values by model of training data.
#
# ypred_test is variable that stored predicted values by model of testing data.

# %% [markdown]
# #### Classification Report

# %%
print("Train Data")
print(classification_report(ytrain,ypred_train))
print("Test Data")
print(classification_report(ytest,ypred_test))
# Out:
# Train Data
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       390
#            1       1.00      1.00      1.00       430
#
#     accuracy                           1.00       820
#    macro avg       1.00      1.00      1.00       820
# weighted avg       1.00      1.00      1.00       820
#
# Test Data
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       109
#            1       0.99      0.97      0.98        96
#
#     accuracy                           0.98       205
#    macro avg       0.98      0.98      0.98       205
# weighted avg       0.98      0.98      0.98       205

# %% [markdown]
# According to classification Report accuracy through DecisionTreeClassifier of training data is 100% and testing data is 96%. This is under fitted model.

# %%
bg=BaggingClassifier(KNeighborsClassifier())
bg.fit(xtrain,ytrain)
ypred_train=bg.predict(xtrain)
ypred_test=bg.predict(xtest)

# %% [markdown]
# Craete a object of this class and pass a module (KNeighborsClassifier) in that and fit() method is used in order to train the model and use it for predictions.
#
# ypred_train is variable that stored predicted values by model of training data.
#
# ypred_test is variable that stored predicted values by model of testing data.

# %% [markdown]
# #### Classification Report

# %%
print("Train Data")
print(classification_report(ytrain,ypred_train))
print("Test Data")
print(classification_report(ytest,ypred_test))
# Out:
# Train Data
#               precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80       390
#            1       0.82      0.83      0.83       430
#
#     accuracy                           0.81       820
#    macro avg       0.81      0.81      0.81       820
# weighted avg       0.81      0.81      0.81       820
#
# Test Data
#               precision    recall  f1-score   support
#
#            0       0.73      0.68      0.70       109
#            1       0.66      0.72      0.69        96
#
#     accuracy                           0.70       205
#    macro avg       0.70      0.70      0.70       205
# weighted avg       0.70      0.70      0.70       205

# %% [markdown]
# According to classification Report accuracy through KNeighborsClassifier of training data is 81% and testing data is 67%. This is best fitted model.

# %% [markdown]
# ## RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier()
rf.fit(xtrain,ytrain)
ypred_train=rf.predict(xtrain)
ypred_test=rf.predict(xtest)

# %% [markdown]
# From class sklearn.ensemble build a model RandomForestClassifier
#
# Craete a object of this class and fit() method is used in order to train the model and use it for predictions.
#
# ypred_train is variable that stored predicted values by model of training data.
#
# ypred_test is variable that stored predicted values by model of testing data.

# %% [markdown]
# #### Classification Report

# %%
print("Train Data")
print(classification_report(ytrain,ypred_train))
print("Test Data")
print(classification_report(ytest,ypred_test))
# Out:
# Train Data
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       390
#            1       1.00      1.00      1.00       430
#
#     accuracy                           1.00       820
#    macro avg       1.00      1.00      1.00       820
# weighted avg       1.00      1.00      1.00       820
#
# Test Data
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       109
#            1       1.00      0.98      0.99        96
#
#     accuracy                           0.99       205
#    macro avg       0.99      0.99      0.99       205
# weighted avg       0.99      0.99      0.99       205

# %% [markdown]
# According to classification Report accuracy of training data is 100% its high bias and testing data is 99% its variance is high. Beacause of this scenario it is underfitted model.

# %% [markdown]
# ## Voting

# %%
from sklearn.ensemble import VotingClassifier

# %% [markdown]
# From class sklearn.ensemble build a model VotingClassifier

# %%
model=[]
accuracy=[]
model.append(("Logistic Regression",LogisticRegression()))
model.append(("Decision Tree",DecisionTreeClassifier()))

# %%
model
# Out:
# [('Logistic Regression', LogisticRegression()),
#  ('Decision Tree', DecisionTreeClassifier())]

# %% [markdown]
# Make a two lists i.e. Model, Accuracy.
# Logistic and Decision Tree algo uppend in the model list.

# %%
vc=VotingClassifier(estimators=model)
vc.fit(xtrain,ytrain)
ypred_train=vc.predict(xtrain)
ypred_test=vc.predict(xtest)

# %% [markdown]
# Craete a object of this class and pass estimators is model and fit() method is used in order to train the model and use it for predictions.
#
# ypred_train is variable that stored predicted values by model of training data.
#
# ypred_test is variable that stored predicted values by model of testing data.

# %% [markdown]
# #### Classification Report

# %%
print("Train Data")
print(classification_report(ytrain,ypred_train))
print("Test Data")
print(classification_report(ytest,ypred_test))
# Out:
# Train Data
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95       390
#            1       1.00      0.90      0.95       430
#
#     accuracy                           0.95       820
#    macro avg       0.95      0.95      0.95       820
# weighted avg       0.95      0.95      0.95       820
#
# Test Data
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.93       109
#            1       0.96      0.85      0.91        96
#
#     accuracy                           0.92       205
#    macro avg       0.92      0.91      0.92       205
# weighted avg       0.92      0.92      0.92       205

# %% [markdown]
# According to classification Report accuracy of training data is 95%  and testing data is 92% . Beacause of this scenario it is under fitted model.

# %% [markdown]
# ## Boosting

# %% [markdown]
# ### AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier
ad=AdaBoostClassifier()
ad.fit(xtrain,ytrain)
ypred_train=ad.predict(xtrain)
ypred_test=ad.predict(xtest)

# %% [markdown]
# From class sklearn.ensemble build a model AdaBoostClassifier
#
# Craete a object of this class and fit() method is used in order to train the model and use it for predictions.
#
# ypred_train is variable that stored predicted values by model of training data.
#
# ypred_test is variable that stored predicted values by model of testing data.

# %% [markdown]
# #### Classification Report

# %%
print("Train Data")
print(classification_report(ytrain,ypred_train))
print("Test Data")
print(classification_report(ytest,ypred_test))
# Out:
# Train Data
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90       390
#            1       0.91      0.92      0.91       430
#
#     accuracy                           0.91       820
#    macro avg       0.91      0.91      0.91       820
# weighted avg       0.91      0.91      0.91       820
#
# Test Data
#               precision    recall  f1-score   support
#
#            0       0.93      0.83      0.87       109
#            1       0.82      0.93      0.87        96
#
#     accuracy                           0.87       205
#    macro avg       0.88      0.88      0.87       205
# weighted avg       0.88      0.87      0.87       205

# %% [markdown]
# According to classification Report accuracy of training data is 91%  and testing data is 87% . Beacause of this scenario it is under fitted model.

# %% [markdown]
# ### GBoost

# %%
from sklearn.ensemble import GradientBoostingClassifier
gd=GradientBoostingClassifier()
gd.fit(xtrain,ytrain)
ypred_train=gd.predict(xtrain)
ypred_test=gd.predict(xtest)

# %% [markdown]
# From class sklearn.ensemble build a model GradientBoostingClassifier
#
# Craete a object of this class and fit() method is used in order to train the model and use it for predictions.
#
# ypred_train is variable that stored predicted values by model of training data.
#
# ypred_test is variable that stored predicted values by model of testing data.

# %% [markdown]
# #### Classification Report

# %%
print("Train Data")
print(classification_report(ytrain,ypred_train))
print("Test Data")
print(classification_report(ytest,ypred_test))
# Out:
# Train Data
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       390
#            1       0.99      0.99      0.99       430
#
#     accuracy                           0.99       820
#    macro avg       0.99      0.99      0.99       820
# weighted avg       0.99      0.99      0.99       820
#
# Test Data
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96       109
#            1       0.94      0.97      0.95        96
#
#     accuracy                           0.96       205
#    macro avg       0.96      0.96      0.96       205
# weighted avg       0.96      0.96      0.96       205

# %% [markdown]
# According to classification Report accuracy of training data is 98%  and testing data is 82% . Beacause of this scenario it is under fitted model.

# %% [markdown]
# ### XGBoost

# %%
from xgboost import XGBClassifier
xg=XGBClassifier()
xg.fit(xtrain,ytrain)
ypred_train=xg.predict(xtrain)
ypred_test=xg.predict(xtest)

# %% [markdown]
# From class sklearn.ensemble build a model XGBClassifier
#
# Craete a object of this class and fit() method is used in order to train the model and use it for predictions.
#
# ypred_train is variable that stored predicted values by model of training data.
#
# ypred_test is variable that stored predicted values by model of testing data.

# %% [markdown]
# #### Classification Report

# %%
print("Train Data")
print(classification_report(ytrain,ypred_train))
print("Test Data")
print(classification_report(ytest,ypred_test))
# Out:
# Train Data
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       390
#            1       1.00      1.00      1.00       430
#
#     accuracy                           1.00       820
#    macro avg       1.00      1.00      1.00       820
# weighted avg       1.00      1.00      1.00       820
#
# Test Data
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       109
#            1       1.00      1.00      1.00        96
#
#     accuracy                           1.00       205
#    macro avg       1.00      1.00      1.00       205
# weighted avg       1.00      1.00      1.00       205

# %% [markdown]
# According to classification Report accuracy of training data is 100% that is high bias and testing data is 100% with high varieance . Beacause of this scenario it is under fitted model.

# %% [markdown]
# # The Best Prediction was done by model trained on Logistic Regression Algoritham with accuracy of 85% on Train Data and 82% on Test Data
